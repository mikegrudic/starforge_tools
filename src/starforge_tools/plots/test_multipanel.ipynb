# %%
# %pylab
# %matplotlib inline

simpath = "/mnt/ceph/users/starforge/STARFORGE_RT/STARFORGE_v1.2/M2e4_R10/M2e4_R10_Z1_S0_A2_B0.1_I1_Res271_n2_sol0.5_42/output"

from starforge_tools.plots.multipanel import multipanel_timelapse_map

multipanel_timelapse_map(simpath)
# Out:
# /mnt/sw/nix/store/viz1rblgqglch09a7g4dcy4sqkhn51vz-dconf-0.40.0-lib/lib/gio/modules/libdconfsettings.so: undefined symbol: g_assertion_message_cmpint
# Failed to load module: /mnt/sw/nix/store/viz1rblgqglch09a7g4dcy4sqkhn51vz-dconf-0.40.0-lib/lib/gio/modules/libdconfsettings.so
# Using matplotlib backend: qtagg
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# /mnt/ceph/users/starforge/STARFORGE_RT/STARFORGE_v1.2/M2e4_R10/M2e4_R10_Z1_S0_A2_B0.1_I1_Res271_n2_sol0.5_42/output
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 8
#       4 simpath = "/mnt/ceph/users/starforge/STARFORGE_RT/STARFORGE_v1.2/M2e4_R10/M2e4_R10_Z1_S0_A2_B0.1_I1_Res271_n2_sol0.5_42/output"
#       6 from starforge_tools.plots.multipanel import multipanel_timelapse_map
# ...

# %%
from rendermap import SurfaceDensity

# %%
import rendermap
getattr(rendermap, "SurfaceDensity").render(2,3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 import rendermap
# ----> 2 getattr(rendermap, "SurfaceDensity").render(2,3,4)
#
# TypeError: SurfaceDensity.render() missing 1 required positional argument: 'mapargs'
