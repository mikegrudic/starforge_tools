# %%
# %pylab
# %matplotlib inline

simpath = "/mnt/ceph/users/starforge/STARFORGE_RT/STARFORGE_v1.2/M2e4_R10/M2e4_R10_Z1_S0_A2_B0.1_I1_Res126_n2_sol0.5_42/output"

from starforge_tools.plots.multipanel import multipanel_timelapse_map

multipanel_timelapse_map(simpath)
# Out:
# Using matplotlib backend: qtagg
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# /mnt/ceph/users/starforge/STARFORGE_RT/STARFORGE_v1.2/M2e4_R10/M2e4_R10_Z1_S0_A2_B0.1_I1_Res126_n2_sol0.5_42/output
# /mnt/home/mgrudic/python_work/lib/python3.11/site-packages/numpy/_core/_methods.py:116: RuntimeWarning: overflow encountered in cast
#   return um.clip(a, min, max, out=out, **kwargs)
# /mnt/home/mgrudic/python_work/lib/python3.11/site-packages/numpy/_core/_methods.py:116: RuntimeWarning: overflow encountered in cast
#   return um.clip(a, min, max, out=out, **kwargs)
